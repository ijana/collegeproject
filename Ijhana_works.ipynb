# %% [markdown]
# <a href="https://colab.research.google.com/github/ijana/collegeproject/blob/master/Ijhana_works.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Open the file in read mode 
text = open("1_oli.txt", "r") 

# Create an empty dictionary 
d = dict() 

# Loop through each line of the file 
for line in text: 
	# Remove the leading spaces and newline character 
	line = line.strip() 

	# Convert the characters in line to 
	# lowercase to avoid case mismatch 
	line = line.lower() 

	# Split the line into words 
	words = line.split(" ") 

	# Iterate over each word in line 
	for word in words: 
		# Check if the word is already in dictionary 
		if word in d: 
			# Increment count of word by 1 
			d[word] = d[word] + 1
		else: 
			# Add the word to dictionary with count 1 
			d[word] = 1

# Print the contents of dictionary 
for key in list(d.keys()): 
	print(key, ":", d[key])
# Out:
# #title: : 1
# small : 1
# parties : 3
# protest : 1
# oli’s : 1
# move : 1
# to : 10
# issue : 3
# ordinances : 5
# on : 2
# parties, : 1
# constitutional : 2
# council : 2
#  : 6
# various : 1
# have : 1
# objected : 1
# the : 24
# government’s : 1
# decision : 2
# two : 3
# related : 1
# operation : 1
# of : 3
# political : 1
# and : 3
# council. : 1
# upon : 1
# a : 3
# recommendation : 1
# from : 1
# government, : 1
# president : 1
# bidya : 1
# devi : 1
# bhandari : 1
# monday : 1
# had : 1
# issued : 1
# amending : 1
# laws. : 1
# one : 1
# ordinance : 2
# allows : 1
# group : 1
# in : 5
# party : 5
# split : 1
# if : 1
# it : 1
# can : 1
# secure : 1
# 40 : 1
# per : 1
# cent : 1
# support : 1
# either : 1
# party’s : 3
# central : 1
# committee : 1
# or : 1
# parliamentary : 1
# party, : 2
# other : 1
# lets : 1
# decide : 2
# without : 1
# main : 2
# opposition : 2
# representation. : 1
# rastriya : 1
# prajatantra : 1
# says : 1
# was : 1
# unnecessary, : 1
# ...

# %%
# Open the file in read mode 
text = open("1_deuba.txt", "r") 

# Create an empty dictionary 
d = dict() 

# Loop through each line of the file 
for line in text: 
	# Remove the leading spaces and newline character 
	line = line.strip() 

	# Convert the characters in line to 
	# lowercase to avoid case mismatch 
	line = line.lower() 

	# Split the line into words 
	words = line.split(" ") 

	# Iterate over each word in line 
	for word in words: 
		# Check if the word is already in dictionary 
		if word in d: 
			# Increment count of word by 1 
			d[word] = d[word] + 1
		else: 
			# Add the word to dictionary with count 1 
			d[word] = 1

# Print the contents of dictionary 
for key in list(d.keys()): 
	print(key, ":", d[key])
# Out:
# #title: : 1
# deuba : 3
# urges : 1
# govt : 1
# to : 6
# expand : 2
# range : 2
# of : 2
# coronavirus : 2
# test : 1
#  : 4
# nepali : 1
# congress : 1
# president : 1
# and : 3
# former : 1
# prime : 1
# minister : 1
# sher : 1
# bahadur : 1
# has : 1
# urged : 1
# the : 12
# government : 3
# tests : 1
# community : 1
# level. : 1
# main : 1
# opposition : 1
# leader : 1
# issued : 1
# a : 1
# statement : 1
# on : 1
# monday : 1
# told : 1
# expedite : 1
# testing : 1
# across : 1
# country. : 1
# meanwhile, : 1
# said : 1
# should : 1
# manage : 1
# sufficient : 1
# medical : 1
# equipment : 1
# relief : 1
# materials : 1
# maintain : 1
# situation : 1
# under : 1
# control : 1
# during : 1
# ongoing : 1
# lockdown. : 1
# he : 1
# requested : 1
# all : 1
# stay : 1
# united : 1
# in : 1
# fight : 1
# against : 1
# epidemic. : 1

# %%
# Open the file in read mode 
text = open("1_prachanda.txt", "r") 

# Create an empty dictionary 
d = dict() 

# Loop through each line of the file 
for line in text: 
	# Remove the leading spaces and newline character 
	line = line.strip() 

	# Convert the characters in line to 
	# lowercase to avoid case mismatch 
	line = line.lower() 

	# Split the line into words 
	words = line.split(" ") 

	# Iterate over each word in line 
	for word in words: 
		# Check if the word is already in dictionary 
		if word in d: 
			# Increment count of word by 1 
			d[word] = d[word] + 1
		else: 
			# Add the word to dictionary with count 1 
			d[word] = 1

# Print the contents of dictionary 
for key in list(d.keys()): 
	print(key, ":", d[key])
# Out:
# #title: : 1
# man : 1
# who : 2
# slapped : 2
# pushpa : 2
# kamal : 2
# dahal : 2
# seven : 2
# years : 2
# ago : 1
# arrested : 5
#  : 4
# padam : 1
# kunwar, : 1
# had : 3
# earned : 1
# notoriety : 1
# for : 1
# slapping : 2
# over : 1
# ago, : 1
# has : 1
# been : 1
# in : 2
# naya : 1
# baneshwar : 1
# of : 6
# kathmandu : 2
# on : 4
# saturday : 1
# evening. : 1
# during : 1
# a : 2
# tea : 1
# party : 2
# bhrikutimandap : 1
# november : 1
# 16, : 1
# 2012, : 1
# kunwar : 3
# the : 12
# then : 1
# chairman : 2
# cpn-maoist : 1
# centre. : 1
# however, : 1
# police : 3
# have : 1
# clarified : 1
# that : 1
# he : 4
# was : 2
# not : 1
# charge : 1
# current : 1
# executive : 1
# ruling : 1
# yesterday. : 2
# dsp : 1
# durga : 1
# raj : 1
# ragmi, : 1
# chief : 1
# metropolitan : 1
# circle, : 1
# baneshwar, : 1
# says : 2
# after : 1
# unauthorisedly : 1
# entered : 2
# parliament : 1
# building : 1
# premises. : 2
# are : 1
# investigating : 1
# why : 1
# scuffle : 1
# ...

# %% [markdown]
# # New Section
